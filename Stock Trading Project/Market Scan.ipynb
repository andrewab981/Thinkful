# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import autocorrelation_plot
from sklearn import metrics

# %matplotlib inline

# %%
# Import the live NASDAQ stock list from nasdaq.com
nasdaq_url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download'
nasdaq_df = pd.read_csv(nasdaq_url)

print('\nThere are {} stocks in the NASDAQ'.format(len(nasdaq_df)))
nasdaq_df.head()
# Out:
# There are 3537 stocks in the NASDAQ
#   Symbol                                    Name  LastSale MarketCap  IPOyear  \
# 0    TXG                      10x Genomics, Inc.   67.8500    $6.52B   2019.0
# 1     YI                               111, Inc.    5.2000  $424.63M   2018.0
# 2    PIH  1347 Property Insurance Holdings, Inc.    4.6200   $27.81M   2014.0
# 3  PIHPP  1347 Property Insurance Holdings, Inc.   25.6981   $17.99M      NaN
# 4   TURN                180 Degree Capital Corp.    2.1650   $67.38M      NaN
#
#           Sector                                          industry  \
# 0  Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 1    Health Care                          Medical/Nursing Services
# 2        Finance                        Property-Casualty Insurers
# 3        Finance                        Property-Casualty Insurers
# 4        Finance                        Finance/Investors Services
#
#                          Summary Quote  Unnamed: 8
# 0    https://old.nasdaq.com/symbol/txg         NaN
# 1     https://old.nasdaq.com/symbol/yi         NaN
# 2    https://old.nasdaq.com/symbol/pih         NaN
# 3  https://old.nasdaq.com/symbol/pihpp         NaN
# 4   https://old.nasdaq.com/symbol/turn         NaN

# %%
# Import the live NYSE stock list from nasdaq.com
nyse_url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nyse&render=download'
nyse_df = pd.read_csv(nyse_url)

print('There are {} stocks in the NYSE'.format(len(nyse_df)))
nyse_df.head()
# Out:
# There are 3133 stocks in the NYSE
#   Symbol                    Name  LastSale MarketCap  IPOyear  \
# 0    DDD  3D Systems Corporation      8.99    $1.06B      NaN
# 1    MMM              3M Company    171.88   $98.84B      NaN
# 2   WBAI         500.com Limited      8.90  $382.48M   2013.0
# 3   WUBA             58.com Inc.     51.55    $7.66B   2013.0
# 4   EGHT                 8x8 Inc     20.69    $2.07B      NaN
#
#               Sector                                         industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services
#
#                         Summary Quote  Unnamed: 8
# 0   https://old.nasdaq.com/symbol/ddd         NaN
# 1   https://old.nasdaq.com/symbol/mmm         NaN
# 2  https://old.nasdaq.com/symbol/wbai         NaN
# 3  https://old.nasdaq.com/symbol/wuba         NaN
# 4  https://old.nasdaq.com/symbol/eght         NaN

# %%
# Concat both the NYSE and NASDAQ stocks 
col = ['Symbol', 'Name', 'MarketCap', 'Sector', 'industry']
df = pd.concat([nasdaq_df[col], nyse_df[col]])
df.shape
# Out:
# (6670, 5)

# %%
api = ['PK5ZLGMKZ4LUIPPTQREM', 'mPGGruw0J5TzflIiWgndeBNh6wVUmFVYnjdH847r', 
       'https://paper-api.alpaca.markets']

api = tradeapi.REST(api[0], api[1], api[2])

# Daily OHLCV dataframe for Ferrari
race_daily = api.polygon.historic_agg('day', 'RACE', limit=250).df

race_daily.head()
# Out:
#                              open      high     low   close  volume
# day
# 2018-11-19 00:00:00-05:00  110.50  110.5397  108.64  108.82  358289
# 2018-11-20 00:00:00-05:00  105.76  107.0400  104.97  105.24  630640
# 2018-11-21 00:00:00-05:00  105.40  107.7900  105.38  106.73  294077
# 2018-11-23 00:00:00-05:00  106.71  107.6600  106.66  106.66  180802
# 2018-11-26 00:00:00-05:00  107.99  109.3900  107.79  109.22  301700

# %%
def add_features(dataframe):
    """Add additional features to the OHLCV dataframes
    Parameters: (dataframe) to add features to
    Return 20, 50, 200 moving averages; bollinger bands; 
    and average volume"""

    df = dataframe
    # Create features for 20, 50, 200 moving averages
    df['20MA'] = df['close'].rolling(window=20).mean()
    df['50MA'] = df['close'].rolling(window=50).mean()
    df['200MA'] = df['close'].rolling(window=200).mean()

    # Create features for upper and lower bollinger bands
    df['20_day_std'] = df['close'].rolling(window=20).std()
    df['upper_band'] = df['20MA'] + (df['20_day_std']*2)
    df['lower_band'] = df['20MA'] - (df['20_day_std']*2)
    df['width_%'] = ((df['upper_band']-
                              df['lower_band'])/df['20MA']) * 100

    # Create feature for average volume
    df['avg_volume'] = df['volume'].rolling(window=20).mean()
    
    return df

# %%
race_daily = add_features(race_daily)
if race_daily['20MA'][-1] > race_daily['50MA'][-1] > race_daily['200MA'][-1]:
    if race_daily['width_%'][-1] < 6:
        print('RACE')
    else:
        print('nope large %')
else:
    print('nope Bearish trend')
# Out:
# nope large %

# %%
race_daily.tail()
# Out:
#                              open    high     low   close  volume      20MA  \
# day
# 2019-11-11 00:00:00-05:00  163.80  164.74  163.54  164.40  321036  159.6315
# 2019-11-12 00:00:00-05:00  164.71  165.31  163.59  165.02  260996  160.0775
# 2019-11-13 00:00:00-05:00  163.99  164.78  163.39  163.86  323041  160.2770
# 2019-11-14 00:00:00-05:00  163.95  165.89  163.62  165.47  310300  160.6700
# 2019-11-15 00:00:00-05:00  166.91  167.50  166.61  167.00  223370  161.2275
#
#                                50MA      200MA  20_day_std  upper_band  \
# day
# 2019-11-11 00:00:00-05:00  155.7118  147.41075    4.802755  169.237010
# 2019-11-12 00:00:00-05:00  155.8520  147.68310    4.871230  169.819960
# 2019-11-13 00:00:00-05:00  155.9294  147.93895    4.943454  170.163908
# 2019-11-14 00:00:00-05:00  156.0012  148.13480    5.031911  170.733822
# 2019-11-15 00:00:00-05:00  156.0790  148.33415    5.087150  171.401800
#
#                            lower_band    width_%  avg_volume
# day
# 2019-11-11 00:00:00-05:00  150.025990  12.034605   430303.75
# 2019-11-12 00:00:00-05:00  150.335040  12.172179   433389.55
# 2019-11-13 00:00:00-05:00  150.390092  12.337276   428652.95
# 2019-11-14 00:00:00-05:00  150.606178  12.527319   425799.70
# 2019-11-15 00:00:00-05:00  151.053200  12.621047   420893.35

# %% [markdown]
# ## Alpaca
# Very bad servers constant error 500. Not very reliable

# %%
def stock_scan(df, api, timeframe='day'):
    
    """
    Parameters: 
    dataframe: Pandas dataframe of stock tickers
    api: api key info to scrape live data
    timeframe: daily, hourly, 5 min, 1 min etc. 
    
    Returns a generated list of tickers that meet the following:

    Bullish Trend: 20 MA > 50 MA > 200 MA
    Bollinger Band Squeeze: Width of bollinger bands < 6 percent
    """
    
    # list of stocks
    stock_list = []
    
    # Log into API
    api = tradeapi.REST(api[0], api[1], api[2])
    
    # Generate timeframe OHLCV datasets for each ticker
    for x in df.iloc[:,0]:
        tmp_df = api.polygon.historic_agg(timeframe, x, limit=250).df
        
        # Add additional features
        tmp_df = add_features(tmp_df)

        # Append to stock list if meets parameters
        if tmp_df['20MA'][-1] > tmp_df['50MA'][-1] > tmp_df['200MA'][-1]:
            if tmp_df['width_%'][-1] < 6:
                stock_list.append(x)
                print(x)
            else:
                print('nope large %')
        else:
            print('nope Bearish trend')

    return stock_list

# %%
api = ['PK5ZLGMKZ4LUIPPTQREM', 'mPGGruw0J5TzflIiWgndeBNh6wVUmFVYnjdH847r', 
       'https://paper-api.alpaca.markets']

watch_list = stock_scan(df, api)
print(watch_list)
# Out:
# nope Bearish trend
# nope Bearish trend
# nope Bearish trend
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-9d943622b5df> in <module>
#       2        'https://paper-api.alpaca.markets']
#       3
# ----> 4 watch_list = stock_scan(df, api)
#       5 print(watch_list)
#
# <ipython-input-23-033f4e4a724d> in stock_scan(dataframe, api, timeframe)
#      21     # Generate timeframe OHLCV datasets for each ticker
#      22     for x in df.iloc[:,0]:
# ---> 23         tmp_df = api.polygon.historic_agg(timeframe, x, limit=250).df
#      24
#      25         # Add additional features
#
# c:\users\andre\desktop\python\lib\site-packages\alpaca_trade_api\polygon\rest.py in historic_agg(self, size, symbol, _from, to, limit)
#      74         if limit is not None:
#      75             params['limit'] = limit
# ---> 76         raw = self.get(path, params)
#      77
#      78         return Aggs(raw)
#
# c:\users\andre\desktop\python\lib\site-packages\alpaca_trade_api\polygon\rest.py in get(self, path, params, version)
#      32
#      33     def get(self, path, params=None, version='v1'):
# ---> 34         return self._request('GET', path, params=params, version=version)
#      35
#      36     def exchanges(self):
#
# c:\users\andre\desktop\python\lib\site-packages\alpaca_trade_api\polygon\rest.py in _request(self, method, path, params, version)
#      28             params['staging'] = 'true'
#      29         resp = self._session.request(method, url, params=params)
# ---> 30         resp.raise_for_status()
#      31         return resp.json()
#      32
#
# c:\users\andre\desktop\python\lib\site-packages\requests\models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/historic/agg/day/PIHPP?limit=250&apiKey=PK5ZLGMKZ4LUIPPTQREM

# %% [markdown]
# ## Alphavantage
# Issues after 5-8 stocks, either with the generate features function or server timeouts

# %%
def stock_scan(df):
    
    """
    Parameters: 
    dataframe: Pandas dataframe of stock tickers
    
    Returns a generated list of tickers that meet the following:

    Bullish Trend: 20 MA > 50 MA > 200 MA
    Bollinger Band Squeeze: Width of bollinger bands < 6 percent
    """
    
    # list of stocks
    stock_list = []
    
    # Generate timeframe OHLCV datasets for each ticker
    for x in df.iloc[:,0]:
        url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&datatype=csv&apikey=B6RB0B3JW7VDR8B4'.format(x)
        tmp_df = pd.read_csv(url)
        
        # Add additional features
        tmp_df = add_features(tmp_df)

        # Append to stock list if meets parameters
        if tmp_df['20MA'].iloc[-1] > tmp_df['50MA'].iloc[-1] > tmp_df['200MA'].iloc[-1]:
            if tmp_df['width_%'].iloc[-1] < 6:
                stock_list.append(x)
                print(x)
            else:
                print('nope large % {}'.format(x))
        else:
            print('nope Bearish trend {}'.format(x))

    return stock_list

# %%
watch_list = stock_scan(df)
print(watch_list)
# Out:
# nope Bearish trend TXG
# nope Bearish trend YI
# nope Bearish trend PIH
# nope Bearish trend PIHPP
# nope Bearish trend TURN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\andre\desktop\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a77d053d00d2> in <module>
# ----> 1 watch_list = stock_scan(df)
#       2 print(watch_list)
#
# <ipython-input-35-bd74a820f774> in stock_scan(df)
#      20
#      21         # Add additional features
# ---> 22         tmp_df = add_features(tmp_df)
#      23
#      24         # Append to stock list if meets parameters
#
# <ipython-input-27-7ea0d361191b> in add_features(dataframe)
#       7     df = dataframe
#       8     # Create features for 20, 50, 200 moving averages
# ----> 9     df['20MA'] = df['close'].rolling(window=20).mean()
#      10     df['50MA'] = df['close'].rolling(window=50).mean()
#      11     df['200MA'] = df['close'].rolling(window=200).mean()
#
# c:\users\andre\desktop\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# c:\users\andre\desktop\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'

# %%
df.head(10)
# Out:
#   Symbol                                    Name MarketCap             Sector  \
# 0    TXG                      10x Genomics, Inc.    $6.52B      Capital Goods
# 1     YI                               111, Inc.  $424.63M        Health Care
# 2    PIH  1347 Property Insurance Holdings, Inc.   $27.81M            Finance
# 3  PIHPP  1347 Property Insurance Holdings, Inc.   $17.99M            Finance
# 4   TURN                180 Degree Capital Corp.   $67.38M            Finance
# 5   FLWS                 1-800 FLOWERS.COM, Inc.  $826.76M  Consumer Services
# 6   BCOW         1895 Bancorp of Wisconsin, Inc.   $48.33M            Finance
# 7   FCCY           1st Constitution Bancorp (NJ)  $168.18M            Finance
# 8   SRCE                  1st Source Corporation    $1.31B            Finance
# 9   VNET                    21Vianet Group, Inc.  $907.01M         Technology
#
#                                            industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                          Medical/Nursing Services
# 2                        Property-Casualty Insurers
# 3                        Property-Casualty Insurers
# 4                        Finance/Investors Services
# 5                            Other Specialty Stores
# 6                                             Banks
# 7                              Savings Institutions
# 8                                       Major Banks
# 9   Computer Software: Programming, Data Processing

# %% [markdown]
# ## Tiingo
# I believe this is the best option of the three. Reliable servers. Am able to download entire maret data as much as I need for 10USD a month. Onl issue is the Unbound Local Error in the function below. I do not know how to fix this error.

# %%
api = '73d3a6aeca232c1374f0c610b84ad43e5700afd1'

# %%
import os
import pandas_datareader as pdr
x = 'RACE'
df1 = pdr.get_data_tiingo(x, api_key=api, )
df1.head()
# Out:
#                                    adjClose    adjHigh     adjLow    adjOpen  \
# symbol date
# RACE   2015-10-21 00:00:00+00:00  53.083762  58.845763  53.083762  57.909558
#        2015-10-22 00:00:00+00:00  54.772791  56.172272  53.759373  55.081642
#        2015-10-23 00:00:00+00:00  54.415682  55.979240  54.309514  55.757253
#        2015-10-26 00:00:00+00:00  53.103065  55.014081  52.634963  55.014081
#        2015-10-27 00:00:00+00:00  51.973829  53.074110  47.640263  52.890730
#
#                                   adjVolume  close  divCash   high     low  \
# symbol date
# RACE   2015-10-21 00:00:00+00:00   22498775  55.00      0.0  60.97  55.000
#        2015-10-22 00:00:00+00:00    4545111  56.75      0.0  58.20  55.700
#        2015-10-23 00:00:00+00:00    1967749  56.38      0.0  58.00  56.270
#        2015-10-26 00:00:00+00:00    1466277  55.02      0.0  57.00  54.535
#        2015-10-27 00:00:00+00:00    5949211  53.85      0.0  54.99  49.360
#
#                                    open  splitFactor    volume
# symbol date
# RACE   2015-10-21 00:00:00+00:00  60.00          1.0  22498775
#        2015-10-22 00:00:00+00:00  57.07          1.0   4545111
#        2015-10-23 00:00:00+00:00  57.77          1.0   1967749
#        2015-10-26 00:00:00+00:00  57.00          1.0   1466277
#        2015-10-27 00:00:00+00:00  54.80          1.0   5949211

# %%
def stock_scan(df, api):
    
    """
    Parameters: 
    dataframe: Pandas dataframe of stock tickers
    
    Returns a generated list of tickers that meet the following:

    Bullish Trend: 20 MA > 50 MA > 200 MA
    Bollinger Band Squeeze: Width of bollinger bands < 6 percent
    """
    
    # list of stocks
    stock_list = []
    
    # Generate timeframe OHLCV datasets for each ticker
    for x in df.iloc[:,0]:
        temp_df = pdr.get_data_tiingo(x, api_key=api)
        
        # Add additional features
        tmp_df = add_features(tmp_df)

        # Append to stock list if meets parameters
        if tmp_df['20MA'].iloc[-1] > tmp_df['50MA'].iloc[-1] > tmp_df['200MA'].iloc[-1]:
            if tmp_df['width_%'].iloc[-1] < 6:
                stock_list.append(x)
                print(x)
            else:
                print('nope large % {}'.format(x))
        else:
            print('nope Bearish trend {}'.format(x))

    return stock_list

# %%
watch_list = stock_scan(df, api)
print(watch_list)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-55-4224ebaa4d11> in <module>
# ----> 1 watch_list = stock_scan(df, api)
#       2 print(watch_list)
#
# <ipython-input-54-5e547532910a> in stock_scan(df, api)
#      20
#      21         # Add additional features
# ---> 22         tmp_df = add_features(tmp_df)
#      23
#      24         # Append to stock list if meets parameters
#
# UnboundLocalError: local variable 'tmp_df' referenced before assignment

# %%
x = ['RACE', 'AMZN', 'AAPL']
for y in x:
    temp_df = pdr.get_data_tiingo(y, api_key=api)
    print(temp_df.head())
# Out:
#                                    adjClose    adjHigh     adjLow    adjOpen  \
# symbol date
# RACE   2015-10-21 00:00:00+00:00  53.083762  58.845763  53.083762  57.909558
#        2015-10-22 00:00:00+00:00  54.772791  56.172272  53.759373  55.081642
#        2015-10-23 00:00:00+00:00  54.415682  55.979240  54.309514  55.757253
#        2015-10-26 00:00:00+00:00  53.103065  55.014081  52.634963  55.014081
#        2015-10-27 00:00:00+00:00  51.973829  53.074110  47.640263  52.890730
#
#                                   adjVolume  close  divCash   high     low  \
# symbol date
# RACE   2015-10-21 00:00:00+00:00   22498775  55.00      0.0  60.97  55.000
#        2015-10-22 00:00:00+00:00    4545111  56.75      0.0  58.20  55.700
#        2015-10-23 00:00:00+00:00    1967749  56.38      0.0  58.00  56.270
#        2015-10-26 00:00:00+00:00    1466277  55.02      0.0  57.00  54.535
#        2015-10-27 00:00:00+00:00    5949211  53.85      0.0  54.99  49.360
#
#                                    open  splitFactor    volume
# symbol date
# RACE   2015-10-21 00:00:00+00:00  60.00          1.0  22498775
#        2015-10-22 00:00:00+00:00  57.07          1.0   4545111
#        2015-10-23 00:00:00+00:00  57.77          1.0   1967749
#        2015-10-26 00:00:00+00:00  57.00          1.0   1466277
#        2015-10-27 00:00:00+00:00  54.80          1.0   5949211
#                                   adjClose  adjHigh  adjLow  adjOpen  \
# symbol date
# AMZN   2014-11-18 00:00:00+00:00    324.93   329.56  323.25   323.99
#        2014-11-19 00:00:00+00:00    326.54   328.40  324.02   327.25
#        2014-11-20 00:00:00+00:00    330.54   332.67  323.33   324.00
#        2014-11-21 00:00:00+00:00    332.63   338.33  331.47   335.42
#        2014-11-24 00:00:00+00:00    335.64   337.39  333.60   334.78
#
#                                   adjVolume   close  divCash    high     low  \
# symbol date
# AMZN   2014-11-18 00:00:00+00:00    3551161  324.93      0.0  329.56  323.25
#        2014-11-19 00:00:00+00:00    3281614  326.54      0.0  328.40  324.02
#        2014-11-20 00:00:00+00:00    3436721  330.54      0.0  332.67  323.33
#        2014-11-21 00:00:00+00:00    4466587  332.63      0.0  338.33  331.47
#        2014-11-24 00:00:00+00:00    2754186  335.64      0.0  337.39  333.60
#
#                                     open  splitFactor   volume
# symbol date
# AMZN   2014-11-18 00:00:00+00:00  323.99          1.0  3551161
#        2014-11-19 00:00:00+00:00  327.25          1.0  3281614
#        2014-11-20 00:00:00+00:00  324.00          1.0  3436721
#        2014-11-21 00:00:00+00:00  335.42          1.0  4466587
#        2014-11-24 00:00:00+00:00  334.78          1.0  2754186
#                                     adjClose     adjHigh      adjLow  \
# symbol date
# AAPL   2014-11-18 00:00:00+00:00  106.088495  106.290621  104.636864
#        2014-11-19 00:00:00+00:00  105.353492  106.336559  104.554176
#        2014-11-20 00:00:00+00:00  106.860248  107.365563  105.518868
#        2014-11-21 00:00:00+00:00  107.007249  108.017878  106.602997
#        2014-11-24 00:00:00+00:00  108.987163  109.120383  107.145062
#
#                                      adjOpen  adjVolume    close  divCash  \
# symbol date
# AAPL   2014-11-18 00:00:00+00:00  104.682802   44223978  115.470      0.0
#        2014-11-19 00:00:00+00:00  106.060933   41869160  114.670      0.0
#        2014-11-20 00:00:00+00:00  105.573993   43395537  116.310      0.0
#        2014-11-21 00:00:00+00:00  107.962753   57179298  116.470      0.0
#        2014-11-24 00:00:00+00:00  107.356375   47450824  118.625      0.0
#
#                                     high     low    open  splitFactor  \
# symbol date
# AAPL   2014-11-18 00:00:00+00:00  115.69  113.89  113.94          1.0
#        2014-11-19 00:00:00+00:00  115.74  113.80  115.44          1.0
#        2014-11-20 00:00:00+00:00  116.86  114.85  114.91          1.0
#        2014-11-21 00:00:00+00:00  117.57  116.03  117.51          1.0
#        2014-11-24 00:00:00+00:00  118.77  116.62  116.85          1.0
#
#                                     volume
# symbol date
# AAPL   2014-11-18 00:00:00+00:00  44223978
#        2014-11-19 00:00:00+00:00  41869160
#        2014-11-20 00:00:00+00:00  43395537
#        2014-11-21 00:00:00+00:00  57179298
#        2014-11-24 00:00:00+00:00  47450824

# %% [markdown]
# # Notes  Issues
# ### 1
# The functions within the scan works. The main issue is the server timing out error. The highest number of tickers i could run through was 9 before the error, so it seems like it is a server dropping issue. Below is the documentation for ALPACA
#
# ALPACA = https://github.com/alpacahq/alpaca-trade-api-python
#
# **Solution idea: is there a way for me to reset the function maybe a nested try and except function before line 24 when the for loop starts?
# **
# Solution Ideas: I may need to buy a server subscription to pull 7k stock info at once.
#
# ### 2
# Tiingo function having issues. Out of the three potential APIs to use, Tiingo is looking like the best / most reliable. Just need to fix the unbound errors
